# %% [markdown]
# - ASSIGNMENT: exam3-4
# - POINTS: 3
# - CATEGORY: final-exam
# - RUBRIC: default
# - RUBRIC_CATEGORIES: technical, presentation
# - RUBRIC_WEIGHTS: 0.9, 0.1
# - DUEDATE: 2019-12-10 20:30:00
# - GRADER: Mingjie Liu

# %% [markdown]
# **This is an exam. You must be present in the exam room to get credit for this problem unless you have prior permission from the instructor. You may not talk during the exam except to ask an instructor a question. By turning this in, you agree that this work is your own, and you did not get unauthorized help to complete it or provide unauthorized help to anyone else. You may not modify your exam answer after the due time without permission.**
#
# The volume of adsorbed gas $V$ was measured as a function of pressure $P_A$ in an experiment with the following obtained data.

# %%
pa = [0.01646543, 0.01478045, 0.01040133, 0.05472332, 0.02111582,
      0.03620419, 0.00200216, 0.03338155, 0.09557526, 0.09737707,
      0.03413141, 0.09889903, 0.04555569, 0.03597297, 0.03717765]

V = [5.85225733e-03, 9.78342897e-03, 6.66702255e-03, 2.71298071e-02,
     1.22235478e-02, 2.15296542e-02, 8.98599589e-05, 1.62216656e-02,
     3.52128403e-02, 3.62671559e-02, 1.54013436e-02, 4.26839512e-02,
     2.17803784e-02, 1.43374049e-02, 1.73655601e-02]

# %% [markdown]
# It is believed that the Langmuir isotherm describes this data (the units of $V_m$ are cm<sup>3</sup> and for $K_A$ they are 1/atm):
#
# $V = \frac{V_m K_A p_A}{1 + K_A p_A}$
#
# Use this model to fit your data and show confidence intervals on your parameter estimates.

# %% [markdown]
# This sorbent is intended to adsorb gas at 10 atm. Use your model to estimate the sorption capacity at this pressure.

# %% [markdown]
# Given there is uncertainty in the estimated parameters, we would like to determine how sensitive is the estimated capacity at 10 atm. A typical way to do this is to compute the sensitivity of the estimated capacity with respect to each parameter:
#
# $S_{K_A} = \frac{dV}{dK_A} \biggr\rvert_{p_A=10}$
#
# and
#
# $S_{V_m} = \frac{dV}{dV_m} \biggr\rvert_{p_A=10}$
#
# In other words, compute the derivative of the model with respect to each parameter, and then evaluate it at $p_A=10$. Calculate each of these sensitivities, and then state which parameter is more important for determining the high pressure adsorption capacity. Note that you should not compute these derivatives analytically.
