# %% [markdown]
# - ASSIGNMENT: rref-1
# - POINTS: 2
# - CATEGORY: homework
# - RUBRIC: default
# - RUBRIC_CATEGORIES: technical, presentation
# - RUBRIC_WEIGHTS: 0.9, 0.1
# - DUEDATE: 2019-11-08 23:59:59
# - GRADER: Yilin Yang

# %% [markdown]
# You see two co-workers are in a heated argument about the following two sets of equations.
#
# One of you has derived this set of equations:
#
# $x - 2y + z = 4$
#
# $2x - 3y - z = 2$
#
# The other has derived
#
# $x + y - 8z = -14$
#
# $3x - 4y - 3z = 0$
#
# $2x - y - 7z = -10$
#
# Coworker 1 argues there can't be a third equation with the given information. Coworker 2 says there has to be, there are three unknowns. Just as they are about to come to blows, you step in and wonder is it possible these are the same set of equations?
#
# Determine the rank for each set of equations. State what this means for each set of equations, and what it means for finding the solution for $x, y, z$.

# %% [markdown]
# You can determine if two sets of equations are the same by comparing the reduced row echelon form for each set. Find the reduced row echelon form for the first set of equations:

# %% [markdown]
# Now find the reduced row echelon form for the second set of equations:

# %% [markdown]
# What can you say about the equations now? Are they the same?
