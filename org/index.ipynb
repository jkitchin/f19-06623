# %% [markdown]
# ## Introduction to 06-623 Mathematical Modeling of Chemical Engineering Processes

# %% [markdown]
# Please report errors/typos and issues at [https://github.com/jkitchin/f19-06623/issues](https://github.com/jkitchin/f19-06623/issues).
#
# ![img](./06623-roadmap.png)
#
# This is a set of course notes. Each link below corresponds to about a 90 minute lecture, and they are in the order the lectures were given.
#
# Table of contents:
#
# 1.  [A brief introduction](00-intro.ipynb)
# 2.  [About Jupyter](01-jupyter.ipynb)
# 3.  [Numerical integration](02-integration-1.ipynb)
# 4.  [First order differential equations](03-fode-1.ipynb)
# 5.  [Families of first order differential equations](04-fode-2.ipynb)
# 6.  [N<sup>th</sup> order ODEs](05-nth-odes.ipynb)
# 7.  [Introduction to nonlinear algebra](07-nla-1.ipynb)
# 8.  [Polynomials and systems of nonlinear algebraic equations](08-nla-2.ipynb)
# 9.  [Boundary value problems](09-bvp.ipynb)
# 10. [Finding minima and maxima in functions](10-min-max.ipynb)
# 11. [Introduction to regression](11-regression.ipynb)
# 12. [Nonlinear regression](12-nonlinear-regression-2.ipynb)
# 13. [Constrained optimization](13-constrained-optimization.ipynb)
# 14. [Introduction to linear algebra](15-intro-linear-algebra.ipynb)
# 15. [Linear algebra](16-linear-algebra.ipynb)
# 16. [Interpolation and eigenvalues](17-linear-algebra-2.ipynb)
# 17. [Linear regression and regularization](18-linear-regression.ipynb)
# 18. [Introduction to derivatives](19-introduction-to-autograd.ipynb)
# 19. [Applications of autograd](20-autograd-applications.ipynb)
# 20. [Introduction to machine learning](21-machine-learning.ipynb)
# 21. [ML and extrapolation](22-ml-2.ipynb)
# 22. [Gaussian process regression](23-gp.ipynb)
#
# That concludes these lectures!
